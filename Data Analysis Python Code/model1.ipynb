# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Lifting 50 times.csv           rise front 50 times.csv
# Lifting first test.csv         rise side 50 times.csv
# Punching 50 times.csv          shaking 50 times.csv
# Punching first test.csv        shoulder pressing 50 times.csv
# model1.ipynb                   visual.ipynb
# parameter1.csv

# %%
data=pd.read_csv('Lifting 50 times.csv')
data.shape
# Out:
# (2246, 19)

# %%
def check_ax1(data):

# %%
max(data[' Ax1'])
# Out:
# 0.08099365234375

# %%
data=data[2:100]
plt.figure(figsize=(15, 6))
plt.title(data.columns.values[1])
plt.plot(data[data.columns.values[0]],data[data.columns.values[1]])
plt.show()
