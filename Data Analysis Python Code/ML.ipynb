# %%
#// gyro_y2_trough, peak, period, gy2min, max, mean, std, 
# ax2min, max, mean, std, gy1min, max, mean, std, ax1min, max, mean, std;

# %%
# !ls
# Out:
# Lifting 50 times.csv           rise front 50 times.csv
# Lifting first test.csv         rise side 50 times.csv
# ML.ipynb                       shaking 50 times.csv
# Punching 50 times.csv          shoulder pressing 50 times.csv
# Punching first test.csv        trd_lifting.txt
# model1.ipynb                   visual.ipynb
# parameter1.csv

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB # Gaussian Naive Bays
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier #stochastic gradient descent
from sklearn.tree import DecisionTreeClassifier

import xgboost as xgb
# Out:
# /Users/Dayou/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
xlabel=['GRY2_trough','GRY2_peak','GRY2_period','GY2_min','GY2_max','GY2_mean','GY2_std','AX2_min','AX2_max',\
        'AX2_mean','AX2_std','GY1_min','GY1_max','GY1_mean','GY1_std','AX1_min','AX1_max','AX1_mean','AX1_std',\
       'GZ1_mean','GZ1_std','GZ1_min','GZ1_max']
len(xlabel)
# Out:
# 23

# %%
def reading_txt(txt_name):
    x = pd.read_table(txt_name)
    x=x[0::2]
    s=pd.DataFrame(columns=xlabel)
    for i in range(len(x)):
        aa=x[x.columns.values[0]][i*2]
        aaa=aa.split(' ')
        aaa = [float(j) for j in aaa]
        s.loc[i]=aaa
    return s

# %%
data=reading_txt('trd_lifting.txt')
data.head()
# Out:
#    GRY2_trough   GRY2_peak  GRY2_period     GY2_min     GY2_max  GY2_mean  \
# 0  -148.033142  126.686096     2.801000 -168.197632  142.959595  5.798658
# 1  -168.708801  168.853760     2.599000 -167.243957  136.146545 -6.613798
# 2  -168.663025  133.766174     2.202000 -165.313721  125.198364  3.174700
# 3  -140.594482  119.117737     2.595999 -137.351990  106.025696 -5.870395
# 4  -115.737915  111.358643     2.646999 -140.151977  112.777710 -0.584862
#
#       GY2_std   AX2_min   AX2_max  AX2_mean    ...      GY1_mean   GY1_std  \
# 0  107.670890 -1.979736 -0.124939 -1.036260    ...     -5.517324  9.002190
# 1  106.762213 -2.000000 -0.178650 -1.091198    ...     -5.824422  9.073016
# 2  104.915863 -1.949097 -0.263794 -1.146824    ...     -6.217957  8.143935
# 3   86.907407 -1.848267 -0.227966 -1.040618    ...     -4.968262  5.613034
# 4   91.162538 -1.840027 -0.209045 -0.867616    ...     -5.886598  5.752788
#
#     AX1_min   AX1_max  AX1_mean   AX1_std   GZ1_mean    GZ1_std   GZ1_min  \
# 0 -0.012817  0.086548  0.029964  0.021261 -42.160034  34.202576  0.446479
# 1 -0.065308  0.073181  0.004441  0.033585 -27.908325  34.118652  1.402567
# 2 -0.065857  0.037781  0.002347  0.023407 -18.844604  14.389038  2.212524
# 3 -0.037964  0.040894  0.009254  0.016203 -15.266418  17.707825  1.750522
# 4 -0.026611  0.061890  0.022145  0.018621 -11.528015  17.913818  2.425801
#
#      GZ1_max
# 0  17.978448
# 1  15.071560
# 2   9.684572
# 3   7.333506
# 4   7.655770
#
# [5 rows x 23 columns]

# %%
data.describe()
# Out:
#        GRY2_trough   GRY2_peak  GRY2_period     GY2_min     GY2_max  \
# count    24.000000   24.000000    24.000000   24.000000   24.000000
# mean   -164.387067  136.152585     2.506875 -169.072787  131.387075
# std      20.099273   15.657037     0.162680   19.030158   15.262127
# min    -193.710327  111.053467     2.202000 -198.730469   98.937988
# 25%    -176.952362  125.114441     2.396502 -182.897568  123.313904
# 50%    -169.754028  134.422302     2.496500 -169.311523  133.090973
# 75%    -151.048660  147.146225     2.598999 -154.434204  142.719269
# max    -115.737915  168.853760     2.802000 -126.106262  156.417847
#
#         GY2_mean     GY2_std    AX2_min    AX2_max   AX2_mean    ...      \
# count  24.000000   24.000000  24.000000  24.000000  24.000000    ...
# mean   -5.770115  107.554061  -1.910835  -0.224106  -1.043305    ...
# std     8.349374   11.469468   0.048869   0.059138   0.062132    ...
# min   -24.414607   83.166307  -2.000000  -0.374573  -1.146824    ...
# 25%    -9.325461  100.292345  -1.953934  -0.242004  -1.068049    ...
# 50%    -5.444953  109.824496  -1.904877  -0.218079  -1.055627    ...
# 75%    -0.844305  116.517720  -1.865601  -0.180206  -1.035817    ...
# max     7.400131  126.955983  -1.840027  -0.124939  -0.867616    ...
#
#         GY1_mean    GY1_std    AX1_min    AX1_max   AX1_mean    AX1_std  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   -5.416634   7.107371  -0.032049   0.057126   0.010168   0.018475
# std     0.443507   1.174832   0.016250   0.013425   0.007968   0.004744
# min    -6.217957   4.916119  -0.065857   0.037781  -0.000770   0.012310
# 25%    -5.817300   6.243037  -0.039963   0.045502   0.004335   0.014685
# 50%    -5.395837   6.990891  -0.032776   0.060699   0.008199   0.018340
# 75%    -5.144860   8.012818  -0.022461   0.064789   0.014988   0.021297
# max    -4.421961   9.073016  -0.006653   0.086548   0.029964   0.033585
#
#         GZ1_mean    GZ1_std    GZ1_min    GZ1_max
# count  24.000000  24.000000  24.000000  24.000000
# mean  -17.211596  22.376378   1.506133   9.302023
# std     7.387003   8.536993   0.654957   3.011490
# min   -42.160034  13.549805   0.319193   5.999223
# 25%   -19.317627  15.291214   1.001465   7.192511
# 50%   -16.269684  18.295288   1.538158   8.086725
# 75%   -12.266159  26.254654   1.897049  10.587335
# max    -8.415222  41.831970   2.547455  17.978448
#
# [8 rows x 23 columns]

# %%
#data.mean(axis=0)
a=data.mean(axis=0)

f = open('output.csv', 'w')
f.write(str(list(a)))
f.close()

# %%
a=data.mean(axis=0)
list(a)
# Out:
# [-164.38706716666661,
#  136.15258535833337,
#  2.5068746541666669,
#  -169.07278696666665,
#  131.38707478249998,
#  -5.7701153162499992,
#  107.55406060791665,
#  -1.910835265833333,
#  -0.2241058345833333,
#  -1.0433050745833332,
#  0.59568160083333321,
#  -18.413543701666665,
#  7.7517827349999999,
#  -5.4166337237500004,
#  7.1073709766666688,
#  -0.032048543333333325,
#  0.05712636333333334,
#  0.010167912916666667,
#  0.018475327083333326,
#  -17.211596171666663,
#  22.376378377083331,
#  1.5061329412499997,
#  9.3020232020833351]
